# %% [markdown]
# <a href="https://colab.research.google.com/github/shanmughamkarthik-eng/numpy/blob/main/basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# 1. CREATING ARRAYS

arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
#Addition

plus_one = arr + 1
print(plus_one)
# Out:
# [2 3 4 5 6]

# %%
plus_ten = arr + 10
print(plus_ten)
# Out:
# [11 12 13 14 15]

# %%
#Multiplication

multiply_seven = arr * 7
print(multiply_seven)
# Out:
# [ 7 14 21 28 35]
